# %%
import pandas as pd

# %%
df = pd.read_excel('7_FINANCIACION.xlsx')

# %%
df
# Out:
#        DZ  OFICINA  PERSONA  SF_FINANCIACION_TP
# 0       7      710   229063                0.00
# 1       7      710   229064                0.00
# 2       7      710   229065                0.00
# 3       7      710   229066                0.00
# 4       7      710   229067                0.00
# 5       7      710   229068                0.00
# 6       7      710   229069                0.00
# 7       7      710   229070                0.00
# 8       7      710   229071                0.00
# 9       7      710   229072                0.00
# 10      7      710   229073                0.00
# 11      7      710   229074                0.00
# 12      7      710   229075                0.00
# 13      7      710   229076                0.00
# 14      7      710   229077                0.00
# 15      7      710   229078                0.00
# 16      7      710   229079                0.00
# 17      7      710   229080                0.00
# 18      7      710   229081                0.00
# ...
